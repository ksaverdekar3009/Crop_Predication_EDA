# %% [markdown]
# <a href="https://colab.research.google.com/github/ksaverdekar3009/Crop_Predication_EDA/blob/main/Crop_Predication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Crop Recommendation using Soil Properties and Weather Prediction.csv')

# %%
df.sample(5)
# Out:
#                Soilcolor    Ph        K        P         N     Zn      S  \
# 3495               brown  5.67   456.00   18.000  0.170000  2.000  13.00
# 1735  dark reddish brown  6.40   202.00    1.420  0.130000  1.530   6.89
# 3474                 red  5.20   181.86    2.260  0.219218  2.180  13.58
# 3595                 red  5.40   123.00    1.000  0.133300  0.900   8.00
# 720                 gray  6.31  2110.32  288.869  0.251800  9.637  42.11
#
#         QV2M-W   QV2M-Sp    QV2M-Su  ...  PRECTOTCORR-W  PRECTOTCORR-Sp  \
# 3495  8.910000  9.480000  12.246667  ...       2.293333        4.610000
# 1735  7.933333  8.403333  11.413333  ...       1.763333        3.246667
# 3474  8.910000  9.480000  12.246667  ...       2.293333        4.610000
# 3595  8.506667  9.340000  12.166667  ...       1.736667        5.203333
# 720   7.183333  7.650000  10.476667  ...       2.073333        2.613333
#
#       PRECTOTCORR-Su  PRECTOTCORR-Au  WD10M  GWETTOP  CLOUD_AMT  WS2M_RANGE  \
# ...

# %%
df.describe()
# Out:
#                 Ph            K            P            N           Zn  \
# count  3867.000000  3867.000000  3867.000000  3867.000000  3867.000000
# mean      5.857295   324.284770    11.349588     0.179153     1.774094
# std       0.676690   202.250133    34.141864     0.066476     1.460809
# min       4.300000    41.134000     0.000000     0.000262     0.100000
# 25%       5.390000   191.000000     2.000000     0.131200     1.100000
# 50%       5.780000   282.000000     4.000000     0.179884     1.500000
# 75%       6.200000   405.000000     7.920000     0.230000     2.060000
# max       8.500000  2119.000000   782.000000     0.695600    45.500000
#
#                  S       QV2M-W      QV2M-Sp      QV2M-Su      QV2M-Au  ...  \
# count  3867.000000  3867.000000  3867.000000  3867.000000  3867.000000  ...
# mean     11.311625     8.346870     9.082508    12.232020    10.990747  ...
# std       5.542094     0.613948     0.790654     0.894970     0.993861  ...
# ...

# %% [markdown]
# # Pandas Profiling

# %%
# !pip install ydata-profiling
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 29.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 68.0 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=a11937d54c735e4e5b7cd01b836ed0bcc831895c8a7b9c4388f5c57d33df0fe7
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...

# %%
profile = ProfileReport(df, title='Data Profiling Report', explorative=True, minimal=True)

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-03-04 12:25:23.288069&quot;&gt;&lt;title&gt;Data Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
from google.colab import files
profile.to_file('crop_report.html')  # Save the report

# Display the HTML in Colab:
from IPython.display import HTML
HTML('crop_report.html')

# Or download the report:
files.download('crop_report.html')
